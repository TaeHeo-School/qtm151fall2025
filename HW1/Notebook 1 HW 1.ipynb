# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# <font size="10"> This is my first Jupyter notebook </span>

# %%
print("My name is Taeseong Heo")
# Out:
# My name is Taeseong Heo
