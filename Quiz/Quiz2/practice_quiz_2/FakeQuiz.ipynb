# %% [markdown]
# 1. A code cell is given that defines a function with one input argument (a number) and one return value (a string). Then a variable is defined, passed to the function, and the output is printed. However, there is a mistake in the code and an error occurs. You have to add a comment to the offending line, briefly explaining what happened. Then run a corrected version of the code in another cell.

# %%
#This is just troubleshooting. I'm pretty confident I can do this

# %% [markdown]
# 2. A code cell is given that defines two lists of numbers, then attempts to define a Numpy array from the entries of the two lists using a mathematical operation. The code cell runs fine, but the output is different than what was intended. You have to add a comment, briefly explaining why the output of the code is doing something differently. Then run a corrected version of the code in another cell.

# %%
#This is just troubleshooting. I'm pretty confident I can do this

# %% [markdown]
# 3. Create a DataFrame by reading in a .csv file. The instructions will refer to a specific column/variable of the DataFrame, and a logical condition.  You will be instructed to extract the subset of the data for which this column/variable satisfies the logical condition. The extracted subset should be saved to a separate DataFrame. Then using Python commands, you will need to print out the number of rows in the extracted data set (i.e., how many rows satisfied the logical condition).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

HeightWeight=pd.read_csv("data_folder/HeightWeight-quiz.csv")

data115to1402=HeightWeight.query("(Weight_Pounds >= 115) and (Weight_Pounds <= 140)")
dataweird4=HeightWeight.query("(Weight_Pounds<95) or (Height_Inches>72)")
print(dataweird4)
print(data115to1402)

num_rows, num_cols = dataweird4.shape
print("Number of rows:", num_rows)
# Out:
#        Index  Height_Inches  Weight_Pounds
# 138      139       73.90107      151.39130
# 154      155       72.44434      136.73970
# 158      159       72.01515      138.77580
# 174      175       73.83364      139.29830
# 234      235       72.74676      135.74580
# ...      ...            ...            ...
# 24801  24802       74.53177      148.91040
# 24835  24836       65.17339       94.40946
# 24883  24884       73.06241      141.50540
# 24921  24922       72.54953      134.51430
# 24939  24940       72.35889      143.95470
#
# [505 rows x 3 columns]
#        Index  Height_Inches  Weight_Pounds
# 1          2       71.51521       136.4873
# 5          6       68.69784       123.3024
# 7          8       70.01472       136.4623
# 9         10       66.78236       120.6672
# 10        11       66.48769       127.4516
# ...      ...            ...            ...
# 24995  24996       69.50215       118.0312
# 24996  24997       64.54826       120.1932
# 24997  24998       64.69855       118.2655
# 24998  24999       67.52918       132.2682
# 24999  25000       68.87761       124.8742
#
# [17965 rows x 3 columns]
# Number of rows: 505

# %% [markdown]
# 4. Write a function that takes in a single number as an input argument, and returns a single string as the output. The value of the output string is one of two choices, which is determined by whether the input satisfies a logical condition. Then use the .apply() method from Pandas to evaluate this function for every row in a DataFrame. You will be told which column/variable should be input to the function.

# %%
# Don't know how to do numbber to string function
# Output string value is 1 of 2 choices, det by logic gate

import pandas as pd
data = {
"A": [1, 2, 3],
"B": [4, 5, 6]
}
df = pd.DataFrame(data)
result = df.apply(lambda x: x + 1)
print(result)

#.apply is in Lec9 with sol
# example in Lec9:
'''
def convert_mpg_to_kmpL(mpg_val):
    return mpg_val*1.609344/3.785411784

car_kmpL = car_mpg.apply(convert_mpg_to_kmpL)
'''
# make sure to check the CSV for specific column name
# Out:
#    A  B
# 0  2  5
# 1  3  6
# 2  4  7
# '\ndef convert_mpg_to_kmpL(mpg_val):\n    return mpg_val*1.609344/3.785411784\n\ncar_kmpL = car_mpg.apply(convert_mpg_to_kmpL)\n'

# %% [markdown]
# 5. Given a DataFrame, you will want to randomly assign each row to one of two groups. To do so, you will add a new column to the DataFrame called "random_var" which is filled with random numbers from a given distribution. Then you will create two new DataFrames, based on the whether each row's random variable satisfies a given logical condition. These two DataFrames represent the random assignment into two groups.

# %%
chisquared_var=np.random.chisquare(df=4, size=1000)
normaldist_var=np.random.normal(loc=0, scale=1, size=1000)

# Adding new column:
heightweight=pd.read_csv("data_folder/HeightWeight-quiz.csv")
num_rows, num_cols = heightweight.shape
group_no = np.random.choice([1, 2, 3], size = num_rows)
heightweight["Group"] = group_no

# Creating new dataframes based off logical condition
def check_low_mileage(mpg):
    if mpg < 20:
        return True
    else:
        return False

car_lo_mileage = car_mpg.apply(check_low_mileage)
car_lo_mileage.name = "Low mileage"

# %%
# DataFrame based off random assignment to groups
import pandas as pd
import numpy as np

heightweight=pd.read_csv("data_folder/HeightWeight-quiz.csv")
num_rows, num_cols = heightweight.shape
group_no = np.random.choice([1, 2], size = num_rows)
heightweight["Group"] = group_no

group1_df = heightweight.query("Group == 1")
group2_df = heightweight.query("Group == 2")
print(type(group1_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 6. Continuing question 5, you will make two scatter plots from the data in each randomly assigned group. So that they appear side-by-side, you will need to use the subplots command from the matplotlib.pyplot library.

# %%
#Side by side scatter plots; but this will need to be scatter based off of CSV data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
n = 500

### Your solution below:

# method 1
vec_x = np.random.normal(loc = 0, scale = 1, size = n)
vec_z = np.random.normal(loc = 5, scale = 1, size = n)

# method 2 (default values are loc = 0, scale = 1, so can omit them)
vec_x = np.random.normal(size = n)
vec_z = np.random.normal(loc = 5, size = n)


# add figsize = (6, 3) or something similar for better sized plots
fig, sub_p = plt.subplots(nrows = 1, ncols = 2)
sub_p[0].scatter(x = vec_x)
sub_p[0].set_xlabel("Samples")
sub_p[0].set_ylabel("Frequency")
sub_p[0].set_title("Normal with mean 0, s.d. 1")

sub_p[1].scatter(x = vec_z)
sub_p[1].set_xlabel("Samples")
sub_p[1].set_ylabel("Frequency")
sub_p[1].set_title("Normal with mean 5, s.d. 1")
plt.tight_layout()
plt.show()

# Scatter plot with legend based off CSV data
df_8 = carfeatures.query("cylinders == 8")
df_4 = carfeatures.query("cylinders == 4")

plt.scatter(x = df_8["weight"],y = df_8["acceleration"])
plt.scatter(x = df_4["weight"],y = df_4["acceleration"])
plt.legend(labels = ["8","4"],
           title  = "Cylinders")

plt.xlabel("Weight")
plt.ylabel("Acceleration")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 19
#      17 # add figsize = (6, 3) or something similar for better sized plots
#      18 fig, sub_p = plt.subplots(nrows = 1, ncols = 2)
# ---> 19 sub_p[0].scatter(x = vec_x)
#      20 sub_p[0].set_xlabel("Samples")
#      21 sub_p[0].set_ylabel("Frequency")
#
# File c:\Users\taehe\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\taehe\anaconda3\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.scatter() missing 1 required positional argument: 'y'
